# %%
import greedy
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 1
# tasks done: 10
# Finished in: 2000s
# press Enter to exit
# tasks done: 14
# Finished in: 4000s
# press Enter to exit
# tasks done: 16
# Finished in: 6000s
# press Enter to exit
# tasks done: 18
# Finished in: 8000s
# press Enter to exit
# tasks done: 20
# Finished in: 10000s
# press Enter to exit
# Calkowita energia: 639.751760255998
# koniec
# 1
# 1
# tasks done: 14
# Finished in: 2000s
# press Enter to exit
# tasks done: 17
# Finished in: 4000s
# press Enter to exit
# tasks done: 19
# Finished in: 6000s
# press Enter to exit
# tasks done: 20
# Finished in: 8000s
# press Enter to exit
# Calkowita energia: 643.4107996946238
# koniec
# 2
# 1
# tasks done: 10
# Finished in: 2000s
# press Enter to exit
# tasks done: 14
# Finished in: 4000s
# press Enter to exit
# tasks done: 17
# Finished in: 6000s
# press Enter to exit
# tasks done: 19
# Finished in: 8000s
# ...
