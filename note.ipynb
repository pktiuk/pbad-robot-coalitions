# %%
import greedy
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 1
# tasks done: 5
# Finished in: 2000s
# press Enter to exit
# tasks done: 6
# Finished in: 4000s
# press Enter to exit
# tasks done: 7
# Finished in: 6000s
# press Enter to exit
# tasks done: 8
# Finished in: 8000s
# press Enter to exit
# tasks done: 9
# Finished in: 10000s
# press Enter to exit
# tasks done: 10
# Finished in: 12000s
# press Enter to exit
# Calkowita energia: 25.129458146347773
# koniec
# 1
# 1
# tasks done: 6
# Finished in: 2000s
# press Enter to exit
# tasks done: 7
# Finished in: 4000s
# press Enter to exit
# tasks done: 8
# Finished in: 6000s
# press Enter to exit
# tasks done: 10
# Finished in: 8000s
# press Enter to exit
# Calkowita energia: 23.10231908189674
# koniec
# 2
# 1
# tasks done: 6
# Finished in: 2000s
# press Enter to exit
# tasks done: 8
# Finished in: 4000s
# press Enter to exit
# tasks done: 9
# Finished in: 6000s
# ...
